# %% [markdown]
# # This notebook mounts MGP_circle_detection from google drive, and then runs ML_analysis.py.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

os.chdir('/content/drive/My Drive/MGP_circle_detection')

# %%
import ML_analysis
# Out:
# :::::Circles found, input to array:::::
# X array: (1, 64, 64)
# :::::Array reshaped for analysis:::::
# X array reshaped: (1, 4096)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# :::::Prediction data (saved to output.csv):::::
#                                   file        p(neg)  p(pos)     x     y   r
# 0  input/input/08099_01_1889-0019L.jpg  3.663736e-14     1.0  1160  1268  89
# Output file written to: output/08099_01_1889-0019L.jpg
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator MLPClassifier from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LabelBinarizer from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator GridSearchCV from version 0.23.1 when using version 0.22.2.post1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
